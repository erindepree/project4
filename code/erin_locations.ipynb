# %% [markdown]
# # Location Coding

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
locations = pd.read_csv('../data/extreme_temp/unique_coordinates.csv').drop(columns=['Unnamed: 0'])

# %%
locations
# Out:
#      latitude  longitude
# 0        50.0       60.0
# 1        50.0       10.0
# 2        20.0     -100.0
# 3       -80.0      150.0
# 4        60.0       60.0
# ..        ...        ...
# 206     -70.0       30.0
# 207      60.0     -150.0
# 208       0.0       20.0
# 209      30.0       90.0
# 210     -20.0       30.0
#
# [211 rows x 2 columns]

# %%
extreme_temp = pd.read_csv('../data/extreme_temp/extreme_temp_2020_2025.csv').drop(columns=['Unnamed: 0'])

# %%
extreme_temp
# Out:
#             date  temp_max  temp_min  latitude  longitude  \
# 0     2021-02-21 -22.45165 -31.61204      50.0       60.0
# 1     2021-02-22  -7.08665 -32.61977      50.0       60.0
# 2     2021-02-25 -21.70254 -31.47707      50.0       60.0
# 3     2021-02-26 -17.15050 -30.80697      50.0       60.0
# 4     2021-03-13 -11.63486 -24.28841      50.0       60.0
# ...          ...       ...       ...       ...        ...
# 2480  2022-04-30  24.60113   8.67733     -20.0       30.0
# 2481  2022-12-01  23.88186  10.91958     -20.0       30.0
# 2482  2022-12-02  27.61004  12.09255     -20.0       30.0
# 2483  2024-03-05  34.28573  18.25308     -20.0       30.0
# 2484  2024-03-06  35.37838  20.87298     -20.0       30.0
#
#       is_above_max_extreme  is_below_min_extreme  is_heat_wave  is_cold_wave  \
# 0                    False                  True         False          True
# 1                    False                  True         False          True
# 2                    False                  True         False          True
# 3                    False                  True         False          True
# 4                    False                  True         False          True
# ...                    ...                   ...           ...           ...
# 2480                 False                  True         False          True
# 2481                 False                  True         False          True
# 2482                 False                  True         False          True
# 2483                  True                 False          True         False
# 2484                  True                 False          True         False
#
#       month  lat_int  long_int
# 0         2       50        60
# 1         2       50        60
# 2         2       50        60
# 3         2       50        60
# 4         3       50        60
# ...     ...      ...       ...
# 2480      4      -20        30
# 2481     12      -20        30
# 2482     12      -20        30
# 2483      3      -20        30
# 2484      3      -20        30
#
# [2485 rows x 12 columns]

# %%
full_data = pd.merge(
    left= extreme_temp, 
    right= locations, 
    left_on= ['lat_int', 'long_int'], 
    right_on=['latitude', 'longitude']
)

# %%
full_data
# Out:
#             date  temp_max  temp_min  latitude_x  longitude_x  \
# 0     2021-02-21 -22.45165 -31.61204        50.0         60.0
# 1     2021-02-22  -7.08665 -32.61977        50.0         60.0
# 2     2021-02-25 -21.70254 -31.47707        50.0         60.0
# 3     2021-02-26 -17.15050 -30.80697        50.0         60.0
# 4     2021-03-13 -11.63486 -24.28841        50.0         60.0
# ...          ...       ...       ...         ...          ...
# 2480  2022-04-30  24.60113   8.67733       -20.0         30.0
# 2481  2022-12-01  23.88186  10.91958       -20.0         30.0
# 2482  2022-12-02  27.61004  12.09255       -20.0         30.0
# 2483  2024-03-05  34.28573  18.25308       -20.0         30.0
# 2484  2024-03-06  35.37838  20.87298       -20.0         30.0
#
#       is_above_max_extreme  is_below_min_extreme  is_heat_wave  is_cold_wave  \
# 0                    False                  True         False          True
# 1                    False                  True         False          True
# 2                    False                  True         False          True
# 3                    False                  True         False          True
# 4                    False                  True         False          True
# ...                    ...                   ...           ...           ...
# 2480                 False                  True         False          True
# 2481                 False                  True         False          True
# 2482                 False                  True         False          True
# 2483                  True                 False          True         False
# 2484                  True                 False          True         False
#
#       month  lat_int  long_int  latitude_y  longitude_y
# 0         2       50        60        50.0         60.0
# 1         2       50        60        50.0         60.0
# 2         2       50        60        50.0         60.0
# 3         2       50        60        50.0         60.0
# 4         3       50        60        50.0         60.0
# ...     ...      ...       ...         ...          ...
# 2480      4      -20        30       -20.0         30.0
# 2481     12      -20        30       -20.0         30.0
# 2482     12      -20        30       -20.0         30.0
# 2483      3      -20        30       -20.0         30.0
# 2484      3      -20        30       -20.0         30.0
#
# [2485 rows x 14 columns]

# %%
data = full_data[full_data['latitude_y'] > -65]

# %%
data.columns
# Out:
# Index(['date', 'temp_max', 'temp_min', 'latitude_x', 'longitude_x',
#        'is_above_max_extreme', 'is_below_min_extreme', 'is_heat_wave',
#        'is_cold_wave', 'month', 'lat_int', 'long_int', 'latitude_y',
#        'longitude_y', 'country', 'region', 'location', 'city', 'notes'],
#       dtype='object')

# %%
data = data.rename(columns={'latitude_y': 'latitude', 'longitude_y': 'longitude'})

# %%
data.columns
# Out:
# Index(['date', 'temp_max', 'temp_min', 'latitude_x', 'longitude_x',
#        'is_above_max_extreme', 'is_below_min_extreme', 'is_heat_wave',
#        'is_cold_wave', 'month', 'lat_int', 'long_int', 'latitude', 'longitude',
#        'country', 'region', 'location', 'city', 'notes'],
#       dtype='object')

# %%
data = data.drop(columns = ['latitude_x', 'longitude_x', 'lat_int', 'long_int', 'location'])

# %%
data
# Out:
#             date  temp_max  temp_min  is_above_max_extreme  \
# 0     2021-02-21 -22.45165 -31.61204                 False
# 1     2021-02-22  -7.08665 -32.61977                 False
# 2     2021-02-25 -21.70254 -31.47707                 False
# 3     2021-02-26 -17.15050 -30.80697                 False
# 4     2021-03-13 -11.63486 -24.28841                 False
# ...          ...       ...       ...                   ...
# 4946  2022-04-30  24.60113   8.67733                 False
# 4947  2022-12-01  23.88186  10.91958                 False
# 4948  2022-12-02  27.61004  12.09255                 False
# 4949  2024-03-05  34.28573  18.25308                  True
# 4950  2024-03-06  35.37838  20.87298                  True
#
#       is_below_min_extreme  is_heat_wave  is_cold_wave  month  latitude  \
# 0                     True         False          True      2        50
# 1                     True         False          True      2        50
# 2                     True         False          True      2        50
# 3                     True         False          True      2        50
# 4                     True         False          True      3        50
# ...                    ...           ...           ...    ...       ...
# 4946                  True         False          True      4       -20
# 4947                  True         False          True     12       -20
# 4948                  True         False          True     12       -20
# 4949                 False          True         False      3       -20
# 4950                 False          True         False      3       -20
#
#       longitude     country region    city notes
# 0            60  Kazakhstan    NaN  Aktobe   NaN
# 1            60  Kazakhstan    NaN  Aktobe   NaN
# 2            60  Kazakhstan    NaN  Aktobe   NaN
# 3            60  Kazakhstan    NaN  Aktobe   NaN
# 4            60  Kazakhstan    NaN  Aktobe   NaN
# ...         ...         ...    ...     ...   ...
# 4946         30    Zimbabwe    NaN  Harare   NaN
# 4947         30    Zimbabwe    NaN  Harare   NaN
# 4948         30    Zimbabwe    NaN  Harare   NaN
# 4949         30    Zimbabwe    NaN  Harare   NaN
# 4950         30    Zimbabwe    NaN  Harare   NaN
#
# [3321 rows x 14 columns]

# %%
loc = locations[locations['latitude']>-65]

# %%
new_df= pd.read_csv('../data/temp_events/monthly_summary_lat=70_long=-130.csv').drop(columns=["Unnamed: 0"])

# %%
new_df['latitude'] = 70
new_df['longitude'] = -130

# %%
new_df.columns
# Out:
# Index(['month', 'max_mean', 'max_std', 'max_extreme', 'min_mean', 'min_std',
#        'min_extreme', 'latitude', 'longitude'],
#       dtype='object')

# %%
extreme_data = pd.DataFrame(columns = ['month', 'max_mean', 'max_std', 'max_extreme', 'min_mean', 'min_std',
       'min_extreme', 'latitude', 'longitude'])

# %%
for i in loc.index:
    lat = loc.loc[i, 'latitude']
    long = loc.loc[i, 'longitude']

    dir_path = '../data/temp_events/'
    file_name = f"monthly_summary_lat={lat}_long={long}.csv"
    
    df = pd.read_csv(dir_path + file_name).drop(columns=['Unnamed: 0'])
    df['latitude'] = lat
    df['longitude'] = long

    extreme_data = pd.concat([extreme_data, df], ignore_index=True)
# Out:
# /var/folders/ty/qfl4p5vd2d3cxdrb54zzgq9w0000gn/T/ipykernel_86911/793604501.py:12: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   extreme_data = pd.concat([extreme_data, df], ignore_index=True)

# %%
extreme_data
# Out:
#      month   max_mean   max_std  max_extreme   min_mean   min_std  \
# 0        1 -10.589673  8.048381     9.531280 -15.676431  8.840515
# 1        2  -7.678298  5.838886     6.918918 -12.897107  7.651830
# 2        3  -6.501635  5.269826     6.672930 -12.802537  6.987687
# 3        4  -1.734576  4.993063    10.748080  -7.282061  6.409844
# 4        5   4.696106  3.745009    14.058627  -0.909495  2.993975
# ...    ...        ...       ...          ...        ...       ...
# 1723     8  10.417553  4.946011    22.782581   4.422825  3.054746
# 1724     9   4.172173  3.751886    13.551889  -0.736435  3.241838
# 1725    10  -8.313387  5.895060     6.424264 -13.388035  6.687279
# 1726    11 -20.964123  6.545296    -4.600882 -25.701555  6.246190
# 1727    12 -27.164062  6.635917   -10.574269 -32.249158  6.551809
#
#       min_extreme latitude longitude
# 0      -37.777719       60      -160
# 1      -32.026683       60      -160
# 2      -30.271754       60      -160
# 3      -23.306671       60      -160
# 4       -8.394434       60      -160
# ...           ...      ...       ...
# 1723    -3.214039       70       150
# 1724    -8.841029       70       150
# 1725   -30.106233       70       150
# 1726   -41.317030       70       150
# 1727   -48.628681       70       150
#
# [1728 rows x 9 columns]

# %%
data.head()
# Out:
#          date  temp_max  temp_min  is_above_max_extreme  is_below_min_extreme  \
# 0  2021-02-21 -22.45165 -31.61204                 False                  True
# 1  2021-02-22  -7.08665 -32.61977                 False                  True
# 2  2021-02-25 -21.70254 -31.47707                 False                  True
# 3  2021-02-26 -17.15050 -30.80697                 False                  True
# 4  2021-03-13 -11.63486 -24.28841                 False                  True
#
#    is_heat_wave  is_cold_wave  month  latitude  longitude     country region  \
# 0         False          True      2        50         60  Kazakhstan    NaN
# 1         False          True      2        50         60  Kazakhstan    NaN
# 2         False          True      2        50         60  Kazakhstan    NaN
# 3         False          True      2        50         60  Kazakhstan    NaN
# 4         False          True      3        50         60  Kazakhstan    NaN
#
#      city notes
# 0  Aktobe   NaN
# 1  Aktobe   NaN
# 2  Aktobe   NaN
# 3  Aktobe   NaN
# 4  Aktobe   NaN

# %%
big_data = pd.merge(
    left= data, 
    right= extreme_data, 
    how= 'inner',
    left_on=['month', 'latitude', 'longitude'], 
    right_on=['month', 'latitude', 'longitude']
).drop(columns=['is_above_max_extreme', 'is_below_min_extreme'])

# %%
big_data.head()
# Out:
#          date  temp_max  temp_min  is_heat_wave  is_cold_wave month latitude  \
# 0  2021-02-21 -22.45165 -31.61204         False          True     2       50
# 1  2021-02-22  -7.08665 -32.61977         False          True     2       50
# 2  2021-02-25 -21.70254 -31.47707         False          True     2       50
# 3  2021-02-26 -17.15050 -30.80697         False          True     2       50
# 4  2021-03-13 -11.63486 -24.28841         False          True     3       50
#
#   longitude     country region    city notes  max_mean   max_std  max_extreme  \
# 0        60  Kazakhstan    NaN  Aktobe   NaN -5.858933  5.901358     8.894463
# 1        60  Kazakhstan    NaN  Aktobe   NaN -5.858933  5.901358     8.894463
# 2        60  Kazakhstan    NaN  Aktobe   NaN -5.858933  5.901358     8.894463
# 3        60  Kazakhstan    NaN  Aktobe   NaN -5.858933  5.901358     8.894463
# 4        60  Kazakhstan    NaN  Aktobe   NaN  1.137817  6.954127    18.523133
#
#     min_mean   min_std  min_extreme
# 0 -13.182437  6.962362   -30.588342
# 1 -13.182437  6.962362   -30.588342
# 2 -13.182437  6.962362   -30.588342
# 3 -13.182437  6.962362   -30.588342
# 4  -7.996859  6.382087   -23.952077

# %%
heat_waves = big_data[big_data['is_heat_wave']==True][[
    'date', 'temp_max', 'temp_min', 'latitude', 'longitude', 
    'country', 'region', 'city', 'notes', 
    'max_mean', 'max_std', 'max_extreme'
]]

# %%
heat_waves
# Out:
#             date  temp_max  temp_min latitude longitude     country region  \
# 8     2022-09-01  34.90664  18.79586       50        60  Kazakhstan    NaN
# 9     2022-09-02  36.77734  21.30377       50        60  Kazakhstan    NaN
# 10    2022-09-03  35.11940  18.95266       50        60  Kazakhstan    NaN
# 13    2023-03-27  18.99990   0.00570       50        60  Kazakhstan    NaN
# 14    2023-03-28  19.69106   1.41110       50        60  Kazakhstan    NaN
# ...          ...       ...       ...      ...       ...         ...    ...
# 3310  2020-01-04  34.72660  19.35720      -20        30    Zimbabwe    NaN
# 3311  2020-01-05  35.32192  20.07010      -20        30    Zimbabwe    NaN
# 3312  2020-01-06  35.53590  21.57280      -20        30    Zimbabwe    NaN
# 3319  2024-03-05  34.28573  18.25308      -20        30    Zimbabwe    NaN
# 3320  2024-03-06  35.37838  20.87298      -20        30    Zimbabwe    NaN
#
#         city notes   max_mean   max_std  max_extreme
# 8     Aktobe   NaN  19.870005  5.656088    34.010225
# 9     Aktobe   NaN  19.870005  5.656088    34.010225
# 10    Aktobe   NaN  19.870005  5.656088    34.010225
# 13    Aktobe   NaN   1.137817  6.954127    18.523133
# 14    Aktobe   NaN   1.137817  6.954127    18.523133
# ...      ...   ...        ...       ...          ...
# 3310  Harare   NaN  26.274844  3.124867    34.087012
# 3311  Harare   NaN  26.274844  3.124867    34.087012
# 3312  Harare   NaN  26.274844  3.124867    34.087012
# 3319  Harare   NaN  26.121787  3.037911    33.716565
# 3320  Harare   NaN  26.121787  3.037911    33.716565
#
# [979 rows x 12 columns]

# %%
heat_waves['std_above_extreme'] = heat_waves.apply(lambda row: (row['temp_max'] - row['max_extreme']) / row['max_std'], axis=1)

# %%
heat_waves
# Out:
#             date  temp_max  temp_min latitude longitude     country region  \
# 8     2022-09-01  34.90664  18.79586       50        60  Kazakhstan    NaN
# 9     2022-09-02  36.77734  21.30377       50        60  Kazakhstan    NaN
# 10    2022-09-03  35.11940  18.95266       50        60  Kazakhstan    NaN
# 13    2023-03-27  18.99990   0.00570       50        60  Kazakhstan    NaN
# 14    2023-03-28  19.69106   1.41110       50        60  Kazakhstan    NaN
# ...          ...       ...       ...      ...       ...         ...    ...
# 3310  2020-01-04  34.72660  19.35720      -20        30    Zimbabwe    NaN
# 3311  2020-01-05  35.32192  20.07010      -20        30    Zimbabwe    NaN
# 3312  2020-01-06  35.53590  21.57280      -20        30    Zimbabwe    NaN
# 3319  2024-03-05  34.28573  18.25308      -20        30    Zimbabwe    NaN
# 3320  2024-03-06  35.37838  20.87298      -20        30    Zimbabwe    NaN
#
#         city notes   max_mean   max_std  max_extreme  std_above_extreme
# 8     Aktobe   NaN  19.870005  5.656088    34.010225           0.158487
# 9     Aktobe   NaN  19.870005  5.656088    34.010225           0.489228
# 10    Aktobe   NaN  19.870005  5.656088    34.010225           0.196103
# 13    Aktobe   NaN   1.137817  6.954127    18.523133           0.068559
# 14    Aktobe   NaN   1.137817  6.954127    18.523133           0.167947
# ...      ...   ...        ...       ...          ...                ...
# 3310  Harare   NaN  26.274844  3.124867    34.087012           0.204677
# 3311  Harare   NaN  26.274844  3.124867    34.087012           0.395187
# 3312  Harare   NaN  26.274844  3.124867    34.087012           0.463664
# 3319  Harare   NaN  26.121787  3.037911    33.716565           0.187354
# 3320  Harare   NaN  26.121787  3.037911    33.716565           0.547026
#
# [979 rows x 13 columns]

# %%
heat_waves = heat_waves.reset_index(drop=True)

# %%
heat_waves['date'] = heat_waves.apply(lambda row: datetime.date(datetime.fromisoformat(row['date'])), axis=1)

# %%
heat_waves
# Out:
#            date  temp_max  temp_min latitude longitude     country region  \
# 0    2022-09-01  34.90664  18.79586       50        60  Kazakhstan    NaN
# 1    2022-09-02  36.77734  21.30377       50        60  Kazakhstan    NaN
# 2    2022-09-03  35.11940  18.95266       50        60  Kazakhstan    NaN
# 3    2023-03-27  18.99990   0.00570       50        60  Kazakhstan    NaN
# 4    2023-03-28  19.69106   1.41110       50        60  Kazakhstan    NaN
# ..          ...       ...       ...      ...       ...         ...    ...
# 974  2020-01-04  34.72660  19.35720      -20        30    Zimbabwe    NaN
# 975  2020-01-05  35.32192  20.07010      -20        30    Zimbabwe    NaN
# 976  2020-01-06  35.53590  21.57280      -20        30    Zimbabwe    NaN
# 977  2024-03-05  34.28573  18.25308      -20        30    Zimbabwe    NaN
# 978  2024-03-06  35.37838  20.87298      -20        30    Zimbabwe    NaN
#
#        city notes   max_mean   max_std  max_extreme  std_above_extreme
# 0    Aktobe   NaN  19.870005  5.656088    34.010225           0.158487
# 1    Aktobe   NaN  19.870005  5.656088    34.010225           0.489228
# 2    Aktobe   NaN  19.870005  5.656088    34.010225           0.196103
# 3    Aktobe   NaN   1.137817  6.954127    18.523133           0.068559
# 4    Aktobe   NaN   1.137817  6.954127    18.523133           0.167947
# ..      ...   ...        ...       ...          ...                ...
# 974  Harare   NaN  26.274844  3.124867    34.087012           0.204677
# 975  Harare   NaN  26.274844  3.124867    34.087012           0.395187
# 976  Harare   NaN  26.274844  3.124867    34.087012           0.463664
# 977  Harare   NaN  26.121787  3.037911    33.716565           0.187354
# 978  Harare   NaN  26.121787  3.037911    33.716565           0.547026
#
# [979 rows x 13 columns]

# %%
heat_waves.to_csv('../data/extreme_temp/heat_waves.csv')

# %%
cold_waves = big_data[big_data['is_cold_wave']==True][[
    'date', 'temp_max', 'temp_min', 'latitude', 'longitude', 
    'country', 'region', 'city', 'notes', 
    'min_mean', 'min_std', 'min_extreme'
]]

# %%
cold_waves['std_below_extreme'] = cold_waves.apply(lambda row: (-row['temp_min'] + row['min_extreme']) / row['min_std'], axis=1)

# %%
cold_waves = cold_waves.reset_index(drop=True)

# %%
cold_waves
# Out:
#             date  temp_max  temp_min latitude longitude     country region  \
# 0     2021-02-21 -22.45165 -31.61204       50        60  Kazakhstan    NaN
# 1     2021-02-22  -7.08665 -32.61977       50        60  Kazakhstan    NaN
# 2     2021-02-25 -21.70254 -31.47707       50        60  Kazakhstan    NaN
# 3     2021-02-26 -17.15050 -30.80697       50        60  Kazakhstan    NaN
# 4     2021-03-13 -11.63486 -24.28841       50        60  Kazakhstan    NaN
# ...          ...       ...       ...      ...       ...         ...    ...
# 2337  2020-02-27  27.36135  12.72924      -20        30    Zimbabwe    NaN
# 2338  2022-04-29  20.91152   8.61123      -20        30    Zimbabwe    NaN
# 2339  2022-04-30  24.60113   8.67733      -20        30    Zimbabwe    NaN
# 2340  2022-12-01  23.88186  10.91958      -20        30    Zimbabwe    NaN
# 2341  2022-12-02  27.61004  12.09255      -20        30    Zimbabwe    NaN
#
#         city notes   min_mean   min_std  min_extreme  std_below_extreme
# 0     Aktobe   NaN -13.182437  6.962362   -30.588342           0.147033
# 1     Aktobe   NaN -13.182437  6.962362   -30.588342           0.291773
# 2     Aktobe   NaN -13.182437  6.962362   -30.588342           0.127647
# 3     Aktobe   NaN -13.182437  6.962362   -30.588342           0.031401
# 4     Aktobe   NaN  -7.996859  6.382087   -23.952077           0.052700
# ...      ...   ...        ...       ...          ...                ...
# 2337  Harare   NaN  17.735753  1.777715    13.291464           0.316262
# 2338  Harare   NaN  14.816893  2.126911     9.499616           0.417688
# 2339  Harare   NaN  14.816893  2.126911     9.499616           0.386610
# 2340  Harare   NaN  18.296606  2.192378    12.815660           0.864851
# 2341  Harare   NaN  18.296606  2.192378    12.815660           0.329829
#
# [2342 rows x 13 columns]

# %%
cold_waves.to_csv('../data/extreme_temp/cold_waves.csv')
